# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Detail_Pekerjaan

# %%
df = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/detail_pekerjaan/benefit.csv')

# %%
df
# Out:
#        id_pekerjaan  benefit                 jenis
# 0        3690843087        0     Medical insurance
# 1        3690843087        0      Dental insurance
# 2        3690843087        0                401(k)
# 3        3690843087        0  Paid maternity leave
# 4        3690843087        0  Disability insurance
# ...             ...      ...                   ...
# 29320    3757934256        0                401(k)
# 29321    3757934256        0  Paid paternity leave
# 29322    3757934256        0  Paid maternity leave
# 29323    3757934256        0  Disability insurance
# 29324    3757498232        1     Medical insurance
#
# [29325 rows x 3 columns]

# %%
df1 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/detail_pekerjaan/industri_pekerjaan.csv')
df1
# Out:
#        id_pekerjaan  id_industri
# 0        3378133231           68
# 1        3497509795           96
# 2        3690843087           47
# 3        3691775263          112
# 4        3691779379           80
# ...             ...          ...
# 44086    3757486249           47
# 44087    3757486249           43
# 44088    3757780487          104
# 44089    3757934256           80
# 44090    3757498232           14
#
# [44091 rows x 2 columns]

# %%
df2 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/detail_pekerjaan/skill_pekerjaan.csv')
df2
# Out:
#        id_pekerjaan singkatan_kemampuan
# 0        3690843087                ACCT
# 1        3690843087                 FIN
# 2        3691763971                MGMT
# 3        3691763971                MNFC
# 4        3691775263                MGMT
# ...             ...                 ...
# 56586    3757780487                HCPR
# 56587    3757934256                DSGN
# 56588    3757934256                 ART
# 56589    3757934256                  IT
# 56590    3757498232                 ADM
#
# [56591 rows x 2 columns]

# %%
df3 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/detail_pekerjaan/upah.csv')
df3
# Out:
#        id_gaji  id_pekerjaan  gaji_maksimal  gaji_median  gaji_minimal  \
# 0            1    3378133231           30.0          NaN          22.0
# 1            2    3690843087        65000.0          NaN       55000.0
# 2            3    3691794313           22.0          NaN          19.0
# 3            4    3691795389        70000.0          NaN       68000.0
# 4            5    3691797089           22.0          NaN          18.0
# ...        ...           ...            ...          ...           ...
# 13347    13736    3756116147       210000.0          NaN      170000.0
# 13348    13737    3757723474       130000.0          NaN      110000.0
# 13349    13738    3757485745            NaN         48.0           NaN
# 13350    13739    3757490898        60000.0          NaN       45000.0
# 13351    13740    3757486249       115000.0          NaN      100000.0
#
#       periode_pembayaran mata_uang jenis_kompensasi
# 0                 HOURLY       USD      BASE_SALARY
# ...

# %% [markdown]
# #Detail_Perusahaan

# %%
df4 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/detail_perusahaan/industri_perusahaan.csv')
df4
# Out:
#        id_perusahaan                               industri
# 0           81149246                       Higher Education
# 1           10033339      Information Technology & Services
# 2            6049228                             Accounting
# 3            2641066  Electrical & Electronic Manufacturing
# 4           96649998                Marketing & Advertising
# ...              ...                                    ...
# 12596       10143362                            Hospitality
# 12597        2293632                   Software Development
# 12598       18754113                Staffing and Recruiting
# 12599       10135152              Government Administration
# 12600         373873          IT Services and IT Consulting
#
# [12601 rows x 2 columns]

# %%
df5 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/detail_perusahaan/jumlah_karyawan.csv')
df5
# Out:
#        id_perusahaan  jumlah_karyawan  jumlah_follower  waktu_dicatat
# 0           81149246                6               91   1.692645e+09
# 1           10033339                3              187   1.692645e+09
# 2            6049228               20               82   1.692645e+09
# 3            2641066               45             2336   1.692645e+09
# 4           96649998                0                2   1.692645e+09
# ...              ...              ...              ...            ...
# 14270         829374             2455            58753   1.699140e+09
# 14271           5574             8281            96163   1.699140e+09
# 14272       10135152             6322            31953   1.699140e+09
# 14273         373873               45            30298   1.699140e+09
# 14274           7428             6901            76462   1.699140e+09
#
# [14275 rows x 4 columns]

# %%
df6 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/detail_perusahaan/perusahaan.csv')
df6
# Out:
#        id_perusahaan                                    nama  \
# 0               1009                                     IBM
# 1               1016                           GE HealthCare
# 2               1021                                GE Power
# 3               1025              Hewlett Packard Enterprise
# 4               1028                                  Oracle
# ...              ...                                     ...
# 11356     3700144594                                  BYREDO
# 11357     3700144710  Pros2Plan, a division of Spinnaker SCA
# 11358     3700147810                       Ascendo Resources
# 11359     3700150295                          The Crox Group
# 11360     3700152513                       Sidley Austin LLP
#
#                                                deskripsi  ukuran_perusahaan  \
# 0      At IBM, we do more than work. We create. We cr...                7.0
# 1      Every day millions of people feel the impact o...                7.0
# ...

# %%
df7 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/detail_perusahaan/spesialisasi_perusahaan.csv')
df7
# Out:
#        id_perusahaan                                       spesialisasi
# 0           81149246                          Childrens Music Education
# 1           81149246                          Foundational Music Theory
# 2           81149246                                Child Music Lessons
# 3           81149246                          social emotional learning
# 4           81149246                       social emotional development
# ...              ...                                                ...
# 78400        2293632                                     LED Billboards
# 78401        2293632                         Electronic Message Centers
# 78402        2293632                                    Digital Signage
# 78403        2293632                            Outdoor Digital Signage
# 78404         373873  System Integrator for ERPs and n-tier web base...
#
# [78405 rows x 2 columns]

# %% [markdown]
# #Mapping

# %%
df8 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/mapping/industri.csv')
df8
# Out:
#      id_industri                             nama_industri
# 0              1           Defense and Space Manufacturing
# 1              3           Computer Hardware Manufacturing
# 2              4                      Software Development
# 3              5              Computer Networking Products
# 4              6      Technology, Information and Internet
# ..           ...                                       ...
# 224         3240         Renewable Energy Power Generation
# 225         3241  Renewable Energy Equipment Manufacturing
# 226         3242                      Engineering Services
# 227         3243             Services for Renewable Energy
# 228         3251  Climate Technology Product Manufacturing
#
# [229 rows x 2 columns]

# %%
df9 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/mapping/kemampuan.csv')
df9
# Out:
#    singkatan_kemampuan          nama_kemampuan
# 0                 PRCH              Purchasing
# 1                 SUPL            Supply Chain
# 2                   PR        Public Relations
# 3                  SCI                 Science
# 4                 STRA       Strategy/Planning
# 5                  WRT         Writing/Editing
# 6                   QA       Quality Assurance
# 7                 DIST            Distribution
# 8                 PROD              Production
# 9                 PRJM      Project Management
# 10                ADVR             Advertising
# 11                RSCH                Research
# 12                  HR         Human Resources
# 13                 LGL                   Legal
# 14                PRDM      Product Management
# 15                MRKT               Marketing
# 16                 EDU               Education
# 17                TRNG                Training
# 18                ANLS                 Analyst
# ...

# %%
df10 = pd.read_csv ('/content/drive/MyDrive/Tim 5C Final Project Drive/Dataset/dataset-6/linkedIn_posting/lowongan_kerja.csv')
df10
# Out:
#        id_pekerjaan  id_perusahaan  \
# 0        3757940104       553718.0
# 1        3757940025      2192142.0
# 2        3757938019       474443.0
# 3        3757938018     18213359.0
# 4        3757937095       437225.0
# ...             ...            ...
# 33241     133114754     77766802.0
# 33242     108965123            NaN
# 33243     102339515     52132271.0
# 33244      85008768            NaN
# 33245       3958427       630152.0
#
#                                                    judul  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...
